# %% [markdown]
# <img src="python_logo.svg" alt="Header" style="width: 300px;"/>

# %%
import pandas as pd
import numpy as np
import pyfpgrowth
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import random
from operator import itemgetter
import collections

# %% [markdown]
# # 1. Prepare The Data

# %% [markdown]
# ### Import Dataset

# %%
# Input dataset name       
input_dataset_name = input('Dataset Name = ')
# Out:
# Dataset Name = EMSC-Data 8 Row - Copy.csv

# %%
data_for_visualization = pd.read_csv('Data/'+input_dataset_name, low_memory=False)
data_for_process = pd.read_csv('Data/'+input_dataset_name, low_memory=False)

# %%
print('Data Before Cleaning :')
data_for_visualization
# Out:
# Data Before Cleaning :
#         Date  Time UTC  Latitude  Longitude  Depth Magnitude Type  Magnitude  \
# 0  3/13/2019   3:24:48     19.34    -155.15      1             Ml        2.1
# 1  6/18/2018  10:29:00     19.42    -155.29      0             ML        2.6
# 2   7/8/2016   3:58:05     40.12      31.64      5             ML        2.1
# 3   3/8/2018  22:27:25     -4.34     152.98     65             mb        4.9
# 4   2/2/2015  12:43:40     35.10      24.32     17             ML        2.0
# 5   5/6/2014  12:58:36     19.34    -155.15      1             ML        3.1
# 6  1/17/2014  10:15:38    -22.75     -68.61    100             ML        3.0
# 7   8/9/2013  13:04:55     38.69      22.66     15             ML        2.6
# 8   7/5/2015   4:20:28     41.05      24.84     15             ML        3.2
# 9   7/3/2015   4:51:58     19.31    -155.39      5             ML        2.3
#
#                   Region Name      Last Update    Eqid  Year  Month  Day
# 0    ISLAND OF HAWAII, HAWAII   3/13/2019 3:30  750458  2019      3   13
# 1    ISLAND OF HAWAII, HAWAII  6/18/2018 10:34  678141  2018      6   18
# 2              WESTERN TURKEY    7/8/2016 4:07  517002  2016      7    8
# 3  NEW BRITAIN REGION, P.N.G.    3/9/2018 7:40  653365  2018      3    8
# 4               CRETE, GREECE   2/3/2015 13:38  425639  2015      2    2
# 5    ISLAND OF HAWAII, HAWAII   5/6/2014 13:12  376680  2014      5    6
# 6          ANTOFAGASTA, CHILE  1/17/2014 10:27  353695  2014      1   17
# 7                      GREECE  8/30/2013 12:20  332139  2013      8    9
# 8                      GREECE    7/5/2015 8:41  449427  2015      7    5
# 9    ISLAND OF HAWAII, HAWAII    7/3/2015 4:58  449211  2015      7    3

# %% [markdown]
# ## 1.1. Data Cleaning

# %% [markdown]
# ### 1.1.1. Handle Missing Value

# %%
# Data Cleaning ( Handle Missing Value )
data_for_process.fillna(method='ffill',inplace=True) # Fill Forward
data_for_process.fillna(method='bfill',inplace=True) # Fill Backward
data_for_visualization.fillna(method='ffill',inplace=True) # Fill Forward
data_for_visualization.fillna(method='bfill',inplace=True) # Fill Backward

# %%
print('Data After Cleaning :')
data_for_visualization
# Out:
# Data After Cleaning :
#         Date  Time UTC  Latitude  Longitude  Depth Magnitude Type  Magnitude  \
# 0  3/13/2019   3:24:48     19.34    -155.15      1             Ml        2.1
# 1  6/18/2018  10:29:00     19.42    -155.29      0             ML        2.6
# 2   7/8/2016   3:58:05     40.12      31.64      5             ML        2.1
# 3   3/8/2018  22:27:25     -4.34     152.98     65             mb        4.9
# 4   2/2/2015  12:43:40     35.10      24.32     17             ML        2.0
# 5   5/6/2014  12:58:36     19.34    -155.15      1             ML        3.1
# 6  1/17/2014  10:15:38    -22.75     -68.61    100             ML        3.0
# 7   8/9/2013  13:04:55     38.69      22.66     15             ML        2.6
# 8   7/5/2015   4:20:28     41.05      24.84     15             ML        3.2
# 9   7/3/2015   4:51:58     19.31    -155.39      5             ML        2.3
#
#                   Region Name      Last Update    Eqid  Year  Month  Day
# 0    ISLAND OF HAWAII, HAWAII   3/13/2019 3:30  750458  2019      3   13
# 1    ISLAND OF HAWAII, HAWAII  6/18/2018 10:34  678141  2018      6   18
# 2              WESTERN TURKEY    7/8/2016 4:07  517002  2016      7    8
# 3  NEW BRITAIN REGION, P.N.G.    3/9/2018 7:40  653365  2018      3    8
# 4               CRETE, GREECE   2/3/2015 13:38  425639  2015      2    2
# 5    ISLAND OF HAWAII, HAWAII   5/6/2014 13:12  376680  2014      5    6
# 6          ANTOFAGASTA, CHILE  1/17/2014 10:27  353695  2014      1   17
# 7                      GREECE  8/30/2013 12:20  332139  2013      8    9
# 8                      GREECE    7/5/2015 8:41  449427  2015      7    5
# 9    ISLAND OF HAWAII, HAWAII    7/3/2015 4:58  449211  2015      7    3

# %%
data_for_visualization.to_csv('Data after Data Cleaning.csv', index = False)

# %% [markdown]
# ### 1.1.2. Check for Numeric Attribute

# %%
print("All Attribute(s) :", list(data_for_visualization.columns))
# Out:
# All Attribute(s) : ['Date', 'Time UTC', 'Latitude', 'Longitude', 'Depth', 'Magnitude Type', 'Magnitude', 'Region Name', 'Last Update', 'Eqid', 'Year', 'Month', 'Day']

# %%
# Check for numeric attribut
numerics = ['int_','int8','int16', 'int32', 'int64','uint8','uint16', 'uint32', 'uint64', 'float_', 'float16', 'float32', 'float64']
attribute_numeric = data_for_visualization.select_dtypes(include=numerics)

# %%
print("Numeric Attribute(s) :",list(attribute_numeric.columns))
# Out:
# Numeric Attribute(s) : ['Latitude', 'Longitude', 'Depth', 'Magnitude', 'Eqid', 'Year', 'Month', 'Day']

# %% [markdown]
# ### 1.1.3. Check for Nominal Attribute

# %%
# Check for nominal attribute
attribute_nominal = data_for_visualization.select_dtypes(include = ['O'])

# %%
print("Nominal Attribute(s) :",list(attribute_nominal.columns))
# Out:
# Nominal Attribute(s) : ['Date', 'Time UTC', 'Magnitude Type', 'Region Name', 'Last Update']

# %% [markdown]
# ### 1.1.4. Transform Nominal to Numeric

# %%
# Transform the nominal attribute values to numeric values
for att_nom in attribute_nominal:
    data_for_visualization[att_nom]=data_for_visualization[att_nom].astype('category').cat.codes

# %% [markdown]
# ### 1.1.5. Check ID in Dataset

# %%
ListOfId = []
for i in data_for_visualization.columns:
    if (data_for_visualization[i].nunique()) == len(data_for_visualization):
        ListOfId.append(i)

# %%
ListOfId
# Out:
# ['Date', 'Time UTC', 'Last Update', 'Eqid']

# %% [markdown]
# Delete ID Column from Dataset

# %%
for i in ListOfId:
    del data_for_process[i]
    del data_for_visualization[i]

# %%
data_for_process
# Out:
#    Latitude  Longitude  Depth Magnitude Type  Magnitude  \
# 0     19.34    -155.15      1             Ml        2.1
# 1     19.42    -155.29      0             ML        2.6
# 2     40.12      31.64      5             ML        2.1
# 3     -4.34     152.98     65             mb        4.9
# 4     35.10      24.32     17             ML        2.0
# 5     19.34    -155.15      1             ML        3.1
# 6    -22.75     -68.61    100             ML        3.0
# 7     38.69      22.66     15             ML        2.6
# 8     41.05      24.84     15             ML        3.2
# 9     19.31    -155.39      5             ML        2.3
#
#                   Region Name  Year  Month  Day
# 0    ISLAND OF HAWAII, HAWAII  2019      3   13
# 1    ISLAND OF HAWAII, HAWAII  2018      6   18
# 2              WESTERN TURKEY  2016      7    8
# 3  NEW BRITAIN REGION, P.N.G.  2018      3    8
# 4               CRETE, GREECE  2015      2    2
# 5    ISLAND OF HAWAII, HAWAII  2014      5    6
# 6          ANTOFAGASTA, CHILE  2014      1   17
# 7                      GREECE  2013      8    9
# 8                      GREECE  2015      7    5
# 9    ISLAND OF HAWAII, HAWAII  2015      7    3

# %% [markdown]
# ### 1.1.6. Check Correlation

# %%
# Check Correlation
corr = data_for_visualization.corr()

# %%
data_for_visualization
# Out:
#    Latitude  Longitude  Depth  Magnitude Type  Magnitude  Region Name  Year  \
# 0     19.34    -155.15      1               1        2.1            3  2019
# 1     19.42    -155.29      0               0        2.6            3  2018
# 2     40.12      31.64      5               0        2.1            5  2016
# 3     -4.34     152.98     65               2        4.9            4  2018
# 4     35.10      24.32     17               0        2.0            1  2015
# 5     19.34    -155.15      1               0        3.1            3  2014
# 6    -22.75     -68.61    100               0        3.0            0  2014
# 7     38.69      22.66     15               0        2.6            2  2013
# 8     41.05      24.84     15               0        3.2            2  2015
# 9     19.31    -155.39      5               0        2.3            3  2015
#
#    Month  Day
# 0      3   13
# 1      6   18
# 2      7    8
# 3      3    8
# 4      2    2
# 5      5    6
# 6      1   17
# 7      8    9
# 8      7    5
# 9      7    3

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data_for_visualization.corr(),annot=True, cmap="RdYlGn")
# fmt= '.1f'
# coolwarm

# %% [markdown]
# Use Column With Correlation Value >= 0,9

# %%
# if the correlation value = 1, remove it 

columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if corr.iloc[i,j] >= 0.9:
            if columns[j]:
                columns[j] = False

# %%
# select the attribute with correlation value less than 0,9
selected_columns = data_for_visualization.columns[columns]

# %%
selected_columns
# Out:
# Index(['Latitude', 'Longitude', 'Depth', 'Magnitude Type', 'Magnitude',
#        'Region Name', 'Year', 'Month', 'Day'],
#       dtype='object')

# %%
# We get the attribute that we will use or process
attribute_to_use = list(selected_columns)

# %%
print("Attribute after check correlation :", attribute_to_use)
# Out:
# Attribute after check correlation : ['Latitude', 'Longitude', 'Depth', 'Magnitude Type', 'Magnitude', 'Region Name', 'Year', 'Month', 'Day']

# %%
# New Dataset with attribute based on attribute we get from visualization
Dataset = data_for_process[attribute_to_use]
Dataset_visual = data_for_visualization[attribute_to_use]
Data_before_transformation = Dataset
Data_visual_before_transformation = Dataset_visual

# %%
print("Dataset Vizualisation before Data Transformation :")
Data_visual_before_transformation
# Out:
# Dataset Vizualisation before Data Transformation :
#    Latitude  Longitude  Depth  Magnitude Type  Magnitude  Region Name  Year  \
# 0     19.34    -155.15      1               1        2.1            3  2019
# 1     19.42    -155.29      0               0        2.6            3  2018
# 2     40.12      31.64      5               0        2.1            5  2016
# 3     -4.34     152.98     65               2        4.9            4  2018
# 4     35.10      24.32     17               0        2.0            1  2015
# 5     19.34    -155.15      1               0        3.1            3  2014
# 6    -22.75     -68.61    100               0        3.0            0  2014
# 7     38.69      22.66     15               0        2.6            2  2013
# 8     41.05      24.84     15               0        3.2            2  2015
# 9     19.31    -155.39      5               0        2.3            3  2015
#
#    Month  Day
# 0      3   13
# 1      6   18
# 2      7    8
# 3      3    8
# 4      2    2
# 5      5    6
# 6      1   17
# 7      8    9
# 8      7    5
# 9      7    3

# %%
print("Dataset before Data Transformation :")
Data_before_transformation
# Out:
# Dataset before Data Transformation :
#    Latitude  Longitude  Depth Magnitude Type  Magnitude  \
# 0     19.34    -155.15      1             Ml        2.1
# 1     19.42    -155.29      0             ML        2.6
# 2     40.12      31.64      5             ML        2.1
# 3     -4.34     152.98     65             mb        4.9
# 4     35.10      24.32     17             ML        2.0
# 5     19.34    -155.15      1             ML        3.1
# 6    -22.75     -68.61    100             ML        3.0
# 7     38.69      22.66     15             ML        2.6
# 8     41.05      24.84     15             ML        3.2
# 9     19.31    -155.39      5             ML        2.3
#
#                   Region Name  Year  Month  Day
# 0    ISLAND OF HAWAII, HAWAII  2019      3   13
# 1    ISLAND OF HAWAII, HAWAII  2018      6   18
# 2              WESTERN TURKEY  2016      7    8
# 3  NEW BRITAIN REGION, P.N.G.  2018      3    8
# 4               CRETE, GREECE  2015      2    2
# 5    ISLAND OF HAWAII, HAWAII  2014      5    6
# 6          ANTOFAGASTA, CHILE  2014      1   17
# 7                      GREECE  2013      8    9
# 8                      GREECE  2015      7    5
# 9    ISLAND OF HAWAII, HAWAII  2015      7    3

# %%
Data_before_transformation.to_csv('Data after Data Selection.csv', index = False)

# %% [markdown]
# ## 1.2. Binning

# %%
# Check for attribute to binning which is attribute in new dataset with numeric values
atribut_mau_dibinning = []
for i in Dataset.columns:
    if i in attribute_numeric:
        atribut_mau_dibinning.append(i)

# %%
print("Attribute(s) for binning")
atribut_mau_dibinning
# Out:
# Attribute(s) for binning
# ['Latitude', 'Longitude', 'Depth', 'Magnitude', 'Year', 'Month', 'Day']

# %% [markdown]
# ### 1.2.1. Binning Process

# %%
# // Binning Process //
dataframelabel = []
for att in atribut_mau_dibinning:
    atribut_name = Dataset[att]
    max_value = atribut_name.max()
    min_value = atribut_name.min()
    n = len(atribut_name)
    cbrt = n ** (1. / 3)
    data_describe = atribut_name.describe()
    Q1 = data_describe['25%']
    Q2 = data_describe['50%']
    Q3 = data_describe['75%']
    interquartile = Q3 - Q1
    
    # Bins
    bins = int(round((max_value - min_value) /  (2 *  (interquartile / cbrt))))

    # Binwidth
    binwidth = round((2 * (interquartile/cbrt)),2)
    
#     print("Length of Data =", n)
#     print("Max Value =", max_value)
#     print("Min Value =", min_value)
#     print("Cuberoot       =", cbrt)
#     print("Q1             =", Q1)
#     print("Q2             =", Q2)
#     print("Q3             =", Q3)
#     print("Interquartile  =", interquartile)
#     print("Number of Bins =", bins)
#     print("Bin Width      =", binwidth)

    # List of bins
    bins_list = []
    for bins_number in range(bins):
    #     bins_list.append("%.2f" % bins_number)
        x = bins_number * binwidth
        jumlah = round((float(max_value) - x),2)
        bins_list.append(jumlah)
    bins_list = sorted(bins_list, key=float)
    
    # List of bin label
    # bin labels
    bin_labels = []
    for label in range(int(bins)):
        value = att + ' ' +str(label)
        bin_labels.append(value)
        
    for i in range(1):
        df_label = pd.DataFrame({'Bins':bins_list,
                             'Label':bin_labels})
        
    dataframelabel.append(df_label)
    
    DataFrameBin = pd.DataFrame({'Bin': bins_list})
    
    # Binning Process
    # select value with header
    data_list = [('nums', Dataset[att])]

    # # Create the labels for the bin
    # bin_labels = ['Lat1','Lat2','Lat3','Lat4','Lat5','Lat6','Lat7','Lat8','Lat9']

    # Create the dataframe object using the data_list
    df = pd.DataFrame.from_dict(collections.OrderedDict(data_list))



    # Define the scope of the bins
    # ['bound1' , 'bound2' = 1]
    # ['bound2' , 'bound3' = 2]
    # ['bound3' , 'bound4' = 3]
    # ['bound4' , 'bound5' = 4]

    # bins = [bound1, bound2, bound3, bound4, bound5]

    # Create the "bins" column using the cut function
    df[att + '_bins'] = pd.cut(df['nums'], bins=bins, labels=bin_labels)
    
    del Dataset[att]
    Dataset[att + '_bins'] = df[att + '_bins']

# %% [markdown]
# ### 1.2.2. Label of Binning

# %%
LabelValue = []
BinsValue = []
for i in dataframelabel:
    for j in i.values:
        BinsValue.append(j[0])
        LabelValue.append(j[1])

# %%
BinsDataFrame = pd.DataFrame({'Bins' : BinsValue,
                       'Label': LabelValue})

# %%
len(BinsDataFrame)
# Out:
# 23

# %%
for f in range(len(atribut_mau_dibinning)):
    g = dataframelabel[f]
    g.to_csv('Nilai Binning %s.csv' %(f), index = False)

# %%
ListOfDictOfBinning = []
for i in range(len(BinsDataFrame)):
    x = {}
    x['Bins'] = BinsDataFrame['Bins'][i]
    x['Label'] = BinsDataFrame['Label'][i]
    ListOfDictOfBinning.append(x)

# %%
ListOfDictOfBinning
# Out:
# [{'Bins': -10.4, 'Label': 'Latitude 0'},
#  {'Bins': 6.75, 'Label': 'Latitude 1'},
#  {'Bins': 23.9, 'Label': 'Latitude 2'},
#  {'Bins': 41.05, 'Label': 'Latitude 3'},
#  {'Bins': -13.99, 'Label': 'Longitude 0'},
#  {'Bins': 152.98, 'Label': 'Longitude 1'},
#  {'Bins': 19.24, 'Label': 'Depth 0'},
#  {'Bins': 32.7, 'Label': 'Depth 1'},
#  {'Bins': 46.16, 'Label': 'Depth 2'},
#  {'Bins': 59.62, 'Label': 'Depth 3'},
#  {'Bins': 73.08, 'Label': 'Depth 4'},
#  {'Bins': 86.54, 'Label': 'Depth 5'},
#  {'Bins': 100.0, 'Label': 'Depth 6'},
#  {'Bins': 3.18, 'Label': 'Magnitude 0'},
#  {'Bins': 4.04, 'Label': 'Magnitude 1'},
#  {'Bins': 4.9, 'Label': 'Magnitude 2'},
#  {'Bins': 2015.98, 'Label': 'Year 0'},
#  {'Bins': 2019.0, 'Label': 'Year 1'},
#  {'Bins': 4.29, 'Label': 'Month 0'},
#  {'Bins': 8.0, 'Label': 'Month 1'},
#  {'Bins': 5.46, 'Label': 'Day 0'},
#  {'Bins': 11.73, 'Label': 'Day 1'},
#  {'Bins': 18.0, 'Label': 'Day 2'}]

# %% [markdown]
# ## 1.3. Labelling

# %%
# Check for attribute to labeled which is attribute in new dataset with nominal values
atribut_mau_dilabel = []
for att_mau_dilabel in Dataset.columns:
    if att_mau_dilabel in attribute_nominal:
        atribut_mau_dilabel.append(att_mau_dilabel)

# %%
atribut_mau_dilabel
# Out:
# ['Magnitude Type', 'Region Name']

# %% [markdown]
# ### 1.3.1. Labelling Process

# %%
# // Labeling Process //
for atribut_label in atribut_mau_dilabel:
    Dataset[atribut_label] = atribut_label + ' ' + Dataset[atribut_label].astype(str)

# %%
Dataset = Dataset

# %% [markdown]
# ## Dataset Ready to Process

# %%
print("Dataset for Process")
Dataset
# Out:
# Dataset for Process
#       Magnitude Type                             Region Name Latitude_bins  \
# 0  Magnitude Type Ml    Region Name ISLAND OF HAWAII, HAWAII    Latitude 2
# 1  Magnitude Type ML    Region Name ISLAND OF HAWAII, HAWAII    Latitude 2
# 2  Magnitude Type ML              Region Name WESTERN TURKEY    Latitude 3
# 3  Magnitude Type mb  Region Name NEW BRITAIN REGION, P.N.G.    Latitude 1
# 4  Magnitude Type ML               Region Name CRETE, GREECE    Latitude 3
# 5  Magnitude Type ML    Region Name ISLAND OF HAWAII, HAWAII    Latitude 2
# 6  Magnitude Type ML          Region Name ANTOFAGASTA, CHILE    Latitude 0
# 7  Magnitude Type ML                      Region Name GREECE    Latitude 3
# 8  Magnitude Type ML                      Region Name GREECE    Latitude 3
# 9  Magnitude Type ML    Region Name ISLAND OF HAWAII, HAWAII    Latitude 2
#
#   Longitude_bins Depth_bins Magnitude_bins Year_bins Month_bins Day_bins
# 0    Longitude 0    Depth 0    Magnitude 0    Year 1    Month 0    Day 2
# 1    Longitude 0    Depth 0    Magnitude 0    Year 1    Month 1    Day 2
# 2    Longitude 1    Depth 0    Magnitude 0    Year 0    Month 1    Day 1
# 3    Longitude 1    Depth 4    Magnitude 2    Year 1    Month 0    Day 1
# 4    Longitude 1    Depth 1    Magnitude 0    Year 0    Month 0    Day 0
# 5    Longitude 0    Depth 0    Magnitude 1    Year 0    Month 1    Day 0
# 6    Longitude 0    Depth 6    Magnitude 1    Year 0    Month 0    Day 2
# 7    Longitude 1    Depth 1    Magnitude 0    Year 0    Month 1    Day 1
# 8    Longitude 1    Depth 1    Magnitude 1    Year 0    Month 1    Day 0
# 9    Longitude 0    Depth 0    Magnitude 0    Year 0    Month 1    Day 0

# %%
Dataset.to_csv('Data after Data Preprocessing.csv', index = False)

# %% [markdown]
# # 2. Rules Mining [ FP-Growth Algorithm ]

# %% [markdown]
# ## 2.1. Frequent Pattern Mining

# %%
# The data set to an array
data = Dataset.values.tolist()
# data = Dataset.T.apply(lambda x: x.dropna().tolist()).tolist()

if len(Dataset) <= 200:
    minsup = 2
else:
    minsup = round(0.01 * len(Dataset))
    
FrequentPattern = pyfpgrowth.find_frequent_patterns(data, minsup)

# %%
FrequentFrame = pd.DataFrame(list(FrequentPattern.items()), columns=['Itemsets', 'support'])

# %%
print("Frequent Pattern")
FrequentFrame
# Out:
# Frequent Pattern
#                                               Itemsets  support
# 0                                (Region Name GREECE,)        2
# 1                        (Depth 1, Region Name GREECE)        2
# 2                     (Latitude 3, Region Name GREECE)        2
# 3                    (Longitude 1, Region Name GREECE)        2
# 4                        (Month 1, Region Name GREECE)        2
# 5                         (Region Name GREECE, Year 0)        2
# 6              (Magnitude Type ML, Region Name GREECE)        2
# 7            (Depth 1, Latitude 3, Region Name GREECE)        2
# 8           (Depth 1, Longitude 1, Region Name GREECE)        2
# 9               (Depth 1, Month 1, Region Name GREECE)        2
# 10               (Depth 1, Region Name GREECE, Year 0)        2
# 11    (Depth 1, Magnitude Type ML, Region Name GREECE)        2
# 12       (Latitude 3, Longitude 1, Region Name GREECE)        2
# 13           (Latitude 3, Month 1, Region Name GREECE)        2
# 14            (Latitude 3, Region Name GREECE, Year 0)        2
# 15   (Latitude 3, Magnitude Type ML, Region Name GR...        2
# 16          (Longitude 1, Month 1, Region Name GREECE)        2
# 17           (Longitude 1, Region Name GREECE, Year 0)        2
# 18   (Longitude 1, Magnitude Type ML, Region Name G...        2
# 19               (Month 1, Region Name GREECE, Year 0)        2
# 20    (Magnitude Type ML, Month 1, Region Name GREECE)        2
# 21     (Magnitude Type ML, Region Name GREECE, Year 0)        2
# 22   (Depth 1, Latitude 3, Longitude 1, Region Name...        2
# 23   (Depth 1, Latitude 3, Month 1, Region Name GRE...        2
# 24   (Depth 1, Latitude 3, Region Name GREECE, Year 0)        2
# 25   (Depth 1, Latitude 3, Magnitude Type ML, Regio...        2
# 26   (Depth 1, Longitude 1, Month 1, Region Name GR...        2
# 27   (Depth 1, Longitude 1, Region Name GREECE, Yea...        2
# 28   (Depth 1, Longitude 1, Magnitude Type ML, Regi...        2
# 29      (Depth 1, Month 1, Region Name GREECE, Year 0)        2
# ..                                                 ...      ...
# 665              (Depth 0, Magnitude Type ML, Month 1)        4
# 666                             (Longitude 1, Month 1)        3
# 667          (Longitude 1, Magnitude Type ML, Month 1)        3
# 668                     (Longitude 1, Month 1, Year 0)        3
# 669  (Longitude 1, Magnitude Type ML, Month 1, Year 0)        3
# 670                         (Longitude 1, Magnitude 0)        3
# 671                (Longitude 1, Magnitude 0, Month 1)        2
# 672      (Longitude 1, Magnitude 0, Magnitude Type ML)        3
# 673                 (Longitude 1, Magnitude 0, Year 0)        3
# 674  (Longitude 1, Magnitude 0, Magnitude Type ML, ...        2
# 675        (Longitude 1, Magnitude 0, Month 1, Year 0)        2
# 676  (Longitude 1, Magnitude 0, Magnitude Type ML, ...        3
# 677  (Longitude 1, Magnitude 0, Magnitude Type ML, ...        2
# 678                              (Longitude 1, Year 0)        4
# 679                   (Longitude 1, Magnitude Type ML)        4
# 680           (Longitude 1, Magnitude Type ML, Year 0)        4
# 681                                     (Magnitude 0,)        6
# 682                   (Magnitude 0, Magnitude Type ML)        5
# 683                              (Magnitude 0, Year 0)        4
# 684           (Magnitude 0, Magnitude Type ML, Year 0)        4
# 685                             (Magnitude 0, Month 1)        4
# 686          (Magnitude 0, Magnitude Type ML, Month 1)        4
# 687                     (Magnitude 0, Month 1, Year 0)        3
# 688  (Magnitude 0, Magnitude Type ML, Month 1, Year 0)        3
# 689                                  (Month 1, Year 0)        5
# 690               (Magnitude Type ML, Month 1, Year 0)        5
# 691                       (Magnitude Type ML, Month 1)        6
# 692                                          (Year 0,)        7
# 693                        (Magnitude Type ML, Year 0)        7
# 694                               (Magnitude Type ML,)        8
#
# [695 rows x 2 columns]

# %%
FrequentFrame.to_csv('Frequent Pattern.csv' ,index=False)

# %% [markdown]
# ## 2.2. Closed Pattern Mining

# %%
# Mining Closed Pattern Function
def issubset(a,b):
    for x in a:
        if x not in b:
            return False
    return True

dictionary = {}

# %%
def close_pattern(freq_pattern):
    satu = []
    for a,b in freq_pattern.items():
        w = a
        flag = False
        for i,j in freq_pattern.items():
            if a!=i and i not in satu:
                #print(a,b,i,j)
                if issubset(a,i) and b == j:
                    flag = True
                    break
        #print(flag)
        if flag == False:
            dictionary[w] = b
        satu.append(w)

    return dictionary

# %%
# Mining Closed Pattern Process
ClosedPattern = close_pattern(FrequentPattern)
ClosedFrame = pd.DataFrame(list(ClosedPattern.items()), columns=['Itemset', 'Support'])

# %%
print("Closed Pattern")
ClosedFrame
# Out:
# Closed Pattern
#                                               Itemset  Support
# 0   (Depth 1, Latitude 3, Longitude 1, Magnitude T...        2
# 1                                   (Month 0, Year 1)        2
# 2                       (Day 2, Longitude 0, Month 0)        2
# 3   (Day 2, Depth 0, Latitude 2, Longitude 0, Magn...        2
# 4             (Day 2, Longitude 0, Magnitude Type ML)        2
# 5                                (Day 2, Longitude 0)        3
# 6                                (Day 1, Longitude 1)        3
# 7   (Day 1, Latitude 3, Longitude 1, Magnitude 0, ...        2
# 8   (Day 0, Depth 1, Latitude 3, Longitude 1, Magn...        2
# 9   (Depth 1, Latitude 3, Longitude 1, Magnitude 0...        2
# 10  (Depth 1, Latitude 3, Longitude 1, Magnitude T...        2
# 11  (Depth 1, Latitude 3, Longitude 1, Magnitude T...        3
# 12  (Longitude 0, Magnitude 1, Magnitude Type ML, ...        2
# 13  (Day 0, Magnitude 1, Magnitude Type ML, Month ...        2
# 14           (Magnitude 1, Magnitude Type ML, Year 0)        3
# 15  (Depth 0, Latitude 2, Longitude 0, Magnitude 0...        3
# 16  (Depth 0, Latitude 2, Longitude 0, Magnitude T...        3
# 17  (Depth 0, Latitude 2, Longitude 0, Magnitude 0...        2
# 18  (Depth 0, Latitude 2, Longitude 0, Region Name...        4
# 19                             (Longitude 0, Month 0)        2
# 20                             (Magnitude 0, Month 0)        2
# 21                             (Longitude 1, Month 0)        2
# 22               (Magnitude Type ML, Month 0, Year 0)        2
# 23  (Latitude 3, Longitude 1, Magnitude Type ML, M...        3
# 24  (Latitude 3, Longitude 1, Magnitude 0, Magnitu...        3
# 25  (Latitude 3, Longitude 1, Magnitude 0, Magnitu...        2
# 26  (Latitude 3, Longitude 1, Magnitude Type ML, Y...        4
# 27  (Day 0, Latitude 3, Longitude 1, Magnitude Typ...        2
# 28    (Day 0, Magnitude 0, Magnitude Type ML, Year 0)        2
# 29  (Day 0, Depth 0, Latitude 2, Longitude 0, Magn...        2
# 30        (Day 0, Magnitude Type ML, Month 1, Year 0)        3
# 31                 (Day 0, Magnitude Type ML, Year 0)        4
# 32           (Longitude 0, Magnitude Type ML, Year 0)        3
# 33                   (Longitude 0, Magnitude Type ML)        4
# 34  (Depth 0, Magnitude 0, Magnitude Type ML, Mont...        2
# 35  (Depth 0, Longitude 0, Magnitude Type ML, Mont...        2
# 36      (Depth 0, Magnitude Type ML, Month 1, Year 0)        3
# 37                             (Depth 0, Longitude 0)        4
# 38                (Depth 0, Longitude 0, Magnitude 0)        3
# 39  (Depth 0, Magnitude 0, Magnitude Type ML, Mont...        3
# 40  (Depth 0, Longitude 0, Magnitude Type ML, Mont...        3
# 41  (Depth 0, Longitude 0, Magnitude 0, Magnitude ...        2
# 42              (Depth 0, Magnitude Type ML, Month 1)        4
# 43  (Longitude 1, Magnitude Type ML, Month 1, Year 0)        3
# 44  (Longitude 1, Magnitude 0, Magnitude Type ML, ...        3
# 45  (Longitude 1, Magnitude 0, Magnitude Type ML, ...        2
# 46           (Longitude 1, Magnitude Type ML, Year 0)        4
# 47                                     (Magnitude 0,)        6
# 48                   (Magnitude 0, Magnitude Type ML)        5
# 49           (Magnitude 0, Magnitude Type ML, Year 0)        4
# 50          (Magnitude 0, Magnitude Type ML, Month 1)        4
# 51  (Magnitude 0, Magnitude Type ML, Month 1, Year 0)        3
# 52               (Magnitude Type ML, Month 1, Year 0)        5
# 53                       (Magnitude Type ML, Month 1)        6
# 54                        (Magnitude Type ML, Year 0)        7
# 55                               (Magnitude Type ML,)        8

# %%
ClosedFrame.to_csv('Closed Pattern.csv', index=False)

# %% [markdown]
# ## 2.3. Association Rules Mining

# %% [markdown]
# ### 2.3.1. Mining Association Rules

# %%
AssociationRules = pyfpgrowth.generate_association_rules(ClosedPattern, 0.8)

# %%
AssociationRules
# Out:
# {('Depth 1',
#   'Latitude 3',
#   'Longitude 1',
#   'Magnitude Type ML',
#   'Month 1',
#   'Year 0'): (('Region Name GREECE',), 1.0),
#  ('Longitude 0', 'Month 0'): (('Day 2',), 1.0),
#  ('Longitude 1',
#   'Magnitude 0',
#   'Magnitude Type ML',
#   'Month 1',
#   'Year 0'): (('Latitude 3',), 1.0),
#  ('Latitude 3',
#   'Longitude 1',
#   'Magnitude 0',
#   'Magnitude Type ML',
#   'Month 1',
#   'Year 0'): (('Day 1',), 1.0),
#  ('Day 0',
#   'Latitude 3',
#   'Longitude 1',
#   'Magnitude Type ML',
#   'Year 0'): (('Depth 1',), 1.0),
#  ('Depth 0',
#   'Longitude 0',
#   'Magnitude 0'): (('Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII'),
#   1.0),
#  ('Depth 0',
#   'Longitude 0',
#   'Magnitude Type ML',
#   'Month 1'): (('Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII'), 1.0),
#  ('Depth 0',
#   'Longitude 0',
#   'Magnitude 0',
#   'Magnitude Type ML',
#   'Month 1'): (('Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII'), 1.0),
#  ('Depth 0',
#   'Longitude 0'): (('Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII'),
#   1.0),
#  ('Longitude 1', 'Magnitude Type ML', 'Month 1', 'Year 0'): (('Latitude 3',),
#   1.0),
#  ('Longitude 1',
#   'Magnitude 0',
#   'Magnitude Type ML',
#   'Year 0'): (('Latitude 3',), 1.0),
#  ('Longitude 1', 'Magnitude Type ML', 'Year 0'): (('Latitude 3',), 1.0),
#  ('Depth 0',
#   'Longitude 0',
#   'Magnitude Type ML',
#   'Month 1',
#   'Year 0'): (('Day 0', 'Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII'),
#   1.0),
#  ('Magnitude 0',): (('Magnitude Type ML',), 0.8333333333333334),
#  ('Magnitude 0', 'Magnitude Type ML'): (('Month 1',), 0.8),
#  ('Magnitude Type ML', 'Month 1'): (('Year 0',), 0.8333333333333334),
#  ('Magnitude Type ML',): (('Year 0',), 0.875)}

# %% [markdown]
# ### 2.3.2. Separate Rules to Antecedence, Consequent and Antecedence Join Consequent

# %%
# // Create new dataframe for Association Rules //

# Separate Association Rules Items ( 'Antecedence', 'Consequent', 'Confidence', 'Antecedence U Consequent')
ante = []
conse = []
anteconse = []
confi = []
for key, value in AssociationRules.items():
    TempKey = []
    TempValue = []
    SortedKey = sorted(key)
    SortedValue = sorted(value[0])
    for itemkey in SortedKey:
        TempKey.append(itemkey)
    for itemvalue in SortedValue:
        TempValue.append(itemvalue)
        
    ante.append(tuple(TempKey))
    conse.append(tuple(TempValue))
    confi.append(value[1])

for i in range(len(ante)):
    combine = (tuple(ante[i]+conse[i]))
    anteconse.append(combine)

# %% [markdown]
# ### 2.3.3. Function to Count Support

# %%
ListDataset = Dataset.values.tolist()

# %%
def CountItem(item):
    sums = 0
    for i in ListDataset:
        flag = True
        for x in item:
            if x not in i:
                flag = False
                break
        if flag == True:
            sums += 1
    return sums

# %%
def CheckSupport(ListItems):
    support = []
    for i in ListItems:
        support.append(CountItem(i))
    return support

# %%
AssociationRules
# Out:
# {('Depth 1',
#   'Latitude 3',
#   'Longitude 1',
#   'Magnitude Type ML',
#   'Month 1',
#   'Year 0'): (('Region Name GREECE',), 1.0),
#  ('Longitude 0', 'Month 0'): (('Day 2',), 1.0),
#  ('Longitude 1',
#   'Magnitude 0',
#   'Magnitude Type ML',
#   'Month 1',
#   'Year 0'): (('Latitude 3',), 1.0),
#  ('Latitude 3',
#   'Longitude 1',
#   'Magnitude 0',
#   'Magnitude Type ML',
#   'Month 1',
#   'Year 0'): (('Day 1',), 1.0),
#  ('Day 0',
#   'Latitude 3',
#   'Longitude 1',
#   'Magnitude Type ML',
#   'Year 0'): (('Depth 1',), 1.0),
#  ('Depth 0',
#   'Longitude 0',
#   'Magnitude 0'): (('Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII'),
#   1.0),
#  ('Depth 0',
#   'Longitude 0',
#   'Magnitude Type ML',
#   'Month 1'): (('Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII'), 1.0),
#  ('Depth 0',
#   'Longitude 0',
#   'Magnitude 0',
#   'Magnitude Type ML',
#   'Month 1'): (('Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII'), 1.0),
#  ('Depth 0',
#   'Longitude 0'): (('Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII'),
#   1.0),
#  ('Longitude 1', 'Magnitude Type ML', 'Month 1', 'Year 0'): (('Latitude 3',),
#   1.0),
#  ('Longitude 1',
#   'Magnitude 0',
#   'Magnitude Type ML',
#   'Year 0'): (('Latitude 3',), 1.0),
#  ('Longitude 1', 'Magnitude Type ML', 'Year 0'): (('Latitude 3',), 1.0),
#  ('Depth 0',
#   'Longitude 0',
#   'Magnitude Type ML',
#   'Month 1',
#   'Year 0'): (('Day 0', 'Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII'),
#   1.0),
#  ('Magnitude 0',): (('Magnitude Type ML',), 0.8333333333333334),
#  ('Magnitude 0', 'Magnitude Type ML'): (('Month 1',), 0.8),
#  ('Magnitude Type ML', 'Month 1'): (('Year 0',), 0.8333333333333334),
#  ('Magnitude Type ML',): (('Year 0',), 0.875)}

# %%
separate_ante = []
separate_conse = []
for key, value in AssociationRules.items():
    separate_ante.append(key)
    separate_conse.append(value[0])
    
RulesForGA = dict(zip(separate_ante, separate_conse))

# %%
RulesForGA
# Out:
# {('Depth 1',
#   'Latitude 3',
#   'Longitude 1',
#   'Magnitude Type ML',
#   'Month 1',
#   'Year 0'): ('Region Name GREECE',),
#  ('Longitude 0', 'Month 0'): ('Day 2',),
#  ('Longitude 1',
#   'Magnitude 0',
#   'Magnitude Type ML',
#   'Month 1',
#   'Year 0'): ('Latitude 3',),
#  ('Latitude 3',
#   'Longitude 1',
#   'Magnitude 0',
#   'Magnitude Type ML',
#   'Month 1',
#   'Year 0'): ('Day 1',),
#  ('Day 0',
#   'Latitude 3',
#   'Longitude 1',
#   'Magnitude Type ML',
#   'Year 0'): ('Depth 1',),
#  ('Depth 0', 'Longitude 0', 'Magnitude 0'): ('Latitude 2',
#   'Region Name ISLAND OF HAWAII, HAWAII'),
#  ('Depth 0', 'Longitude 0', 'Magnitude Type ML', 'Month 1'): ('Latitude 2',
#   'Region Name ISLAND OF HAWAII, HAWAII'),
#  ('Depth 0',
#   'Longitude 0',
#   'Magnitude 0',
#   'Magnitude Type ML',
#   'Month 1'): ('Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII'),
#  ('Depth 0', 'Longitude 0'): ('Latitude 2',
#   'Region Name ISLAND OF HAWAII, HAWAII'),
#  ('Longitude 1', 'Magnitude Type ML', 'Month 1', 'Year 0'): ('Latitude 3',),
#  ('Longitude 1',
#   'Magnitude 0',
#   'Magnitude Type ML',
#   'Year 0'): ('Latitude 3',),
#  ('Longitude 1', 'Magnitude Type ML', 'Year 0'): ('Latitude 3',),
#  ('Depth 0',
#   'Longitude 0',
#   'Magnitude Type ML',
#   'Month 1',
#   'Year 0'): ('Day 0', 'Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII'),
#  ('Magnitude 0',): ('Magnitude Type ML',),
#  ('Magnitude 0', 'Magnitude Type ML'): ('Month 1',),
#  ('Magnitude Type ML', 'Month 1'): ('Year 0',),
#  ('Magnitude Type ML',): ('Year 0',)}

# %%
def FindAntecedence(Rules):
    ante = []
    for key, value in Rules.items():
        TempKey = []
        TempValue = []
        SortedKey = sorted(key)
        SortedValue = sorted(value)

        for itemkey in SortedKey:
            TempKey.append(itemkey)

        for itemvalue in SortedValue:
            TempValue.append(itemvalue)

        ante.append(tuple(TempKey))

    return ante
    
def FindConsequent(Rules):
    conse = []
    for key, value in Rules.items():
        TempKey = []
        TempValue = []
        SortedKey = sorted(key)
        SortedValue = sorted(value)

        for itemkey in SortedKey:
            TempKey.append(itemkey)

        for itemvalue in SortedValue:
            TempValue.append(itemvalue)

        conse.append(tuple(TempValue))

    return conse
    
def FindAntecedenceConsequent(Rules):
    # // Create new dataframe for Association Rules //

    # Separate Association Rules Items ( 'Antecedence', 'Consequent', 'Confidence', 'Antecedence U Consequent')
    ante = []
    conse = []
    anteconse = []
    for key, value in Rules.items():
        TempKey = []
        TempValue = []
        SortedKey = sorted(key)
        SortedValue = sorted(value)
        for itemkey in SortedKey:
            TempKey.append(itemkey)
        for itemvalue in SortedValue:
            TempValue.append(itemvalue)

        ante.append(tuple(TempKey))
        conse.append(tuple(TempValue))

    for i in range(len(ante)):
        combine = (tuple(ante[i]+conse[i]))
        anteconse.append(combine)

    return anteconse

def FindAnteConse(Rules):
    # // Create new dataframe for Association Rules //

    # Separate Association Rules Items ( 'Antecedence', 'Consequent', 'Confidence', 'Antecedence U Consequent')
    ante = []
    conse = []
        
    for key, value in Rules.items():
        ante.append(sorted(key))
        conse.append(sorted(value))
            
    result = []
    for i in range(len(ante)):
        Temp = 'If %s, Then %s' %(ante[i], conse[i])
        result.append(Temp)
            
    return result

# %%
def Encode(list_of_rules):
    encode = []
    for i in list_of_rules:
        temp = []
        for j in semua_nilai_dari_atribut:
            if j in i[0]:
                temp.append('00')
            elif j in i[1]:
                temp.append('11')
            else:
                temp.append('01')
        encode.append(temp)
    return encode

def RouletteWheel(Individu):
    maxi = sum(Individu.values())
    pick = random.uniform(0, maxi)
    current = 0
    for key, value in Individu.items():
        current += value
        if current > pick:
            return key
        
def Encode(list_of_rules):
    encode = []
    for i in list_of_rules:
        temp = []
        for j in semua_nilai_dari_atribut:
            if j in i[0]:
                temp.append('00')
            elif j in i[1]:
                temp.append('11')
            else:
                temp.append('01')
        encode.append(temp)
    return encode

def CheckRules(list_encode ,role, index):
    return list_encode[index][role]

def CountAnteConse(list_encode, role, index):
    value = list_encode[index].count(role)
    return value

def ListOfMutationPoints(Offspring, MutationProbability):
    ListOfMutationPoint = []
    for i in range(len(Offspring)):
        RandomValue = random.sample(range(0, len(Offspring[0])), MutationProbability)
        ListOfMutationPoint.append(RandomValue)
    return ListOfMutationPoint

def Decode(list_of_encode):
    decode = {}
    for i in range(len(list_of_encode)):
        ante_decode = []
        conse_decode = []
        for j in range(len(list_of_encode[i])):
            if list_of_encode[i][j] == '00':
                ante_decode.append(semua_nilai_dari_atribut[j])
            elif list_of_encode[i][j] == '11':
                conse_decode.append(semua_nilai_dari_atribut[j])
        result_ante = tuple(ante_decode)
        result_conse = tuple(conse_decode)
        decode[result_ante] = result_conse
    return decode

# %%
AssosiationFrame = pd.DataFrame({'Rules': FindAnteConse(RulesForGA),
                                          'Antecedence': FindAntecedence(RulesForGA) ,
                                          'Consequent': FindConsequent(RulesForGA) ,
                                          'sup(A)': CheckSupport(FindAntecedence(RulesForGA)),
                                          'sup(B)' : CheckSupport(FindConsequent(RulesForGA)),
                                          'sup(A U B)' : CheckSupport(FindAntecedenceConsequent(RulesForGA))
                                        })

AssosiationFrame['Kulczynski'] = round((AssosiationFrame['sup(A U B)'] / 2) * ( ( 1/AssosiationFrame['sup(A)'] ) +  ( 1/AssosiationFrame['sup(B)'] )), 4)
AssosiationFrame['IR'] = (abs(AssosiationFrame['sup(A)'] - AssosiationFrame['sup(B)'])) / (AssosiationFrame['sup(A)'] + AssosiationFrame['sup(B)'] - AssosiationFrame['sup(A U B)'])
AssosiationFrame = AssosiationFrame.sort_values('Kulczynski', ascending=False)
AssosiationFrame = AssosiationFrame[AssosiationFrame['sup(A)'] >= minsup]
AssosiationFrame = AssosiationFrame[AssosiationFrame['sup(B)'] >= minsup]
AssosiationFrame = AssosiationFrame[AssosiationFrame['sup(A U B)'] >= minsup]

# %%
AssosiationFrame.to_csv('Hasil/Rules Awal.csv', index = False)

# %%
AssosiationFrame
# Out:
#                                                 Rules  \
# 0   If ['Depth 1', 'Latitude 3', 'Longitude 1', 'M...
# 11  If ['Longitude 1', 'Magnitude Type ML', 'Year ...
# 12  If ['Depth 0', 'Longitude 0', 'Magnitude Type ...
# 8   If ['Depth 0', 'Longitude 0'], Then ['Latitude...
# 16          If ['Magnitude Type ML'], Then ['Year 0']
# 5   If ['Depth 0', 'Longitude 0', 'Magnitude 0'], ...
# 6   If ['Depth 0', 'Longitude 0', 'Magnitude Type ...
# 9   If ['Longitude 1', 'Magnitude Type ML', 'Month...
# 10  If ['Longitude 1', 'Magnitude 0', 'Magnitude T...
# 4   If ['Day 0', 'Latitude 3', 'Longitude 1', 'Mag...
# 1       If ['Longitude 0', 'Month 0'], Then ['Day 2']
# 3   If ['Latitude 3', 'Longitude 1', 'Magnitude 0'...
# 15  If ['Magnitude Type ML', 'Month 1'], Then ['Ye...
# 7   If ['Depth 0', 'Longitude 0', 'Magnitude 0', '...
# 2   If ['Longitude 1', 'Magnitude 0', 'Magnitude T...
# 14  If ['Magnitude 0', 'Magnitude Type ML'], Then ...
# 13     If ['Magnitude 0'], Then ['Magnitude Type ML']
#
#                                           Antecedence  \
# 0   (Depth 1, Latitude 3, Longitude 1, Magnitude T...
# 11           (Longitude 1, Magnitude Type ML, Year 0)
# 12  (Depth 0, Longitude 0, Magnitude Type ML, Mont...
# 8                              (Depth 0, Longitude 0)
# 16                               (Magnitude Type ML,)
# 5                 (Depth 0, Longitude 0, Magnitude 0)
# 6   (Depth 0, Longitude 0, Magnitude Type ML, Mont...
# 9   (Longitude 1, Magnitude Type ML, Month 1, Year 0)
# 10  (Longitude 1, Magnitude 0, Magnitude Type ML, ...
# 4   (Day 0, Latitude 3, Longitude 1, Magnitude Typ...
# 1                              (Longitude 0, Month 0)
# 3   (Latitude 3, Longitude 1, Magnitude 0, Magnitu...
# 15                       (Magnitude Type ML, Month 1)
# 7   (Depth 0, Longitude 0, Magnitude 0, Magnitude ...
# 2   (Longitude 1, Magnitude 0, Magnitude Type ML, ...
# 14                   (Magnitude 0, Magnitude Type ML)
# 13                                     (Magnitude 0,)
#
#                                            Consequent  sup(A)  sup(B)  \
# 0                               (Region Name GREECE,)       2       2
# 11                                      (Latitude 3,)       4       4
# 12  (Day 0, Latitude 2, Region Name ISLAND OF HAWA...       2       2
# 8   (Latitude 2, Region Name ISLAND OF HAWAII, HAW...       4       4
# 16                                          (Year 0,)       8       7
# 5   (Latitude 2, Region Name ISLAND OF HAWAII, HAW...       3       4
# 6   (Latitude 2, Region Name ISLAND OF HAWAII, HAW...       3       4
# 9                                       (Latitude 3,)       3       4
# 10                                      (Latitude 3,)       3       4
# 4                                          (Depth 1,)       2       3
# 1                                            (Day 2,)       2       3
# 3                                            (Day 1,)       2       3
# 15                                          (Year 0,)       6       7
# 7   (Latitude 2, Region Name ISLAND OF HAWAII, HAW...       2       4
# 2                                       (Latitude 3,)       2       4
# 14                                         (Month 1,)       5       6
# 13                               (Magnitude Type ML,)       6       8
#
#     sup(A U B)  Kulczynski        IR
# 0            2      1.0000  0.000000
# 11           4      1.0000  0.000000
# 12           2      1.0000  0.000000
# 8            4      1.0000  0.000000
# 16           7      0.9375  0.125000
# 5            3      0.8750  0.250000
# 6            3      0.8750  0.250000
# 9            3      0.8750  0.250000
# 10           3      0.8750  0.250000
# 4            2      0.8333  0.333333
# 1            2      0.8333  0.333333
# 3            2      0.8333  0.333333
# 15           5      0.7738  0.125000
# 7            2      0.7500  0.500000
# 2            2      0.7500  0.500000
# 14           4      0.7333  0.142857
# 13           5      0.7292  0.222222

# %%
semua_nilai_dari_atribut = []
for nama_kolom in Dataset.columns:
    temp_data = sorted(Dataset[nama_kolom].unique())
    semua_nilai_dari_atribut.extend(temp_data)

# %% [markdown]
# # ! INPUT FOR GA

# %%
RulesForGA
# Out:
# {('Depth 1',
#   'Latitude 3',
#   'Longitude 1',
#   'Magnitude Type ML',
#   'Month 1',
#   'Year 0'): ('Region Name GREECE',),
#  ('Longitude 0', 'Month 0'): ('Day 2',),
#  ('Longitude 1',
#   'Magnitude 0',
#   'Magnitude Type ML',
#   'Month 1',
#   'Year 0'): ('Latitude 3',),
#  ('Latitude 3',
#   'Longitude 1',
#   'Magnitude 0',
#   'Magnitude Type ML',
#   'Month 1',
#   'Year 0'): ('Day 1',),
#  ('Day 0',
#   'Latitude 3',
#   'Longitude 1',
#   'Magnitude Type ML',
#   'Year 0'): ('Depth 1',),
#  ('Depth 0', 'Longitude 0', 'Magnitude 0'): ('Latitude 2',
#   'Region Name ISLAND OF HAWAII, HAWAII'),
#  ('Depth 0', 'Longitude 0', 'Magnitude Type ML', 'Month 1'): ('Latitude 2',
#   'Region Name ISLAND OF HAWAII, HAWAII'),
#  ('Depth 0',
#   'Longitude 0',
#   'Magnitude 0',
#   'Magnitude Type ML',
#   'Month 1'): ('Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII'),
#  ('Depth 0', 'Longitude 0'): ('Latitude 2',
#   'Region Name ISLAND OF HAWAII, HAWAII'),
#  ('Longitude 1', 'Magnitude Type ML', 'Month 1', 'Year 0'): ('Latitude 3',),
#  ('Longitude 1',
#   'Magnitude 0',
#   'Magnitude Type ML',
#   'Year 0'): ('Latitude 3',),
#  ('Longitude 1', 'Magnitude Type ML', 'Year 0'): ('Latitude 3',),
#  ('Depth 0',
#   'Longitude 0',
#   'Magnitude Type ML',
#   'Month 1',
#   'Year 0'): ('Day 0', 'Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII'),
#  ('Magnitude 0',): ('Magnitude Type ML',),
#  ('Magnitude 0', 'Magnitude Type ML'): ('Month 1',),
#  ('Magnitude Type ML', 'Month 1'): ('Year 0',),
#  ('Magnitude Type ML',): ('Year 0',)}

# %%
AssosiationRulesDataFrameForGA = pd.DataFrame({'Rules': FindAnteConse(RulesForGA),
                                          'Antecedence': FindAntecedence(RulesForGA) ,
                                          'Consequent': FindConsequent(RulesForGA) ,
                                          'sup(A)': CheckSupport(FindAntecedence(RulesForGA)),
                                          'sup(B)' : CheckSupport(FindConsequent(RulesForGA)),
                                          'sup(A U B)' : CheckSupport(FindAntecedenceConsequent(RulesForGA))
                                        })

AssosiationRulesDataFrameForGA['Kulczynski'] = round((AssosiationRulesDataFrameForGA['sup(A U B)'] / 2) * ( ( 1/AssosiationRulesDataFrameForGA['sup(A)'] ) +  ( 1/AssosiationRulesDataFrameForGA['sup(B)'] )), 4)
AssosiationRulesDataFrameForGA['IR'] = (abs(AssosiationRulesDataFrameForGA['sup(A)'] - AssosiationRulesDataFrameForGA['sup(B)'])) / (AssosiationRulesDataFrameForGA['sup(A)'] + AssosiationRulesDataFrameForGA['sup(B)'] - AssosiationRulesDataFrameForGA['sup(A U B)'])
AssosiationRulesDataFrameForGA = AssosiationRulesDataFrameForGA.sort_values('Kulczynski', ascending=False)
AssosiationRulesDataFrameForGA = AssosiationRulesDataFrameForGA[AssosiationRulesDataFrameForGA['sup(A)'] >= minsup]
AssosiationRulesDataFrameForGA = AssosiationRulesDataFrameForGA[AssosiationRulesDataFrameForGA['sup(B)'] >= minsup]
AssosiationRulesDataFrameForGA = AssosiationRulesDataFrameForGA[AssosiationRulesDataFrameForGA['sup(A U B)'] >= minsup]

# %%
AssosiationRulesDataFrameForGA
# Out:
#                                                 Rules  \
# 0   If ['Depth 1', 'Latitude 3', 'Longitude 1', 'M...
# 11  If ['Longitude 1', 'Magnitude Type ML', 'Year ...
# 12  If ['Depth 0', 'Longitude 0', 'Magnitude Type ...
# 8   If ['Depth 0', 'Longitude 0'], Then ['Latitude...
# 16          If ['Magnitude Type ML'], Then ['Year 0']
# 5   If ['Depth 0', 'Longitude 0', 'Magnitude 0'], ...
# 6   If ['Depth 0', 'Longitude 0', 'Magnitude Type ...
# 9   If ['Longitude 1', 'Magnitude Type ML', 'Month...
# 10  If ['Longitude 1', 'Magnitude 0', 'Magnitude T...
# 4   If ['Day 0', 'Latitude 3', 'Longitude 1', 'Mag...
# 1       If ['Longitude 0', 'Month 0'], Then ['Day 2']
# 3   If ['Latitude 3', 'Longitude 1', 'Magnitude 0'...
# 15  If ['Magnitude Type ML', 'Month 1'], Then ['Ye...
# 7   If ['Depth 0', 'Longitude 0', 'Magnitude 0', '...
# 2   If ['Longitude 1', 'Magnitude 0', 'Magnitude T...
# 14  If ['Magnitude 0', 'Magnitude Type ML'], Then ...
# 13     If ['Magnitude 0'], Then ['Magnitude Type ML']
#
#                                           Antecedence  \
# 0   (Depth 1, Latitude 3, Longitude 1, Magnitude T...
# 11           (Longitude 1, Magnitude Type ML, Year 0)
# 12  (Depth 0, Longitude 0, Magnitude Type ML, Mont...
# 8                              (Depth 0, Longitude 0)
# 16                               (Magnitude Type ML,)
# 5                 (Depth 0, Longitude 0, Magnitude 0)
# 6   (Depth 0, Longitude 0, Magnitude Type ML, Mont...
# 9   (Longitude 1, Magnitude Type ML, Month 1, Year 0)
# 10  (Longitude 1, Magnitude 0, Magnitude Type ML, ...
# 4   (Day 0, Latitude 3, Longitude 1, Magnitude Typ...
# 1                              (Longitude 0, Month 0)
# 3   (Latitude 3, Longitude 1, Magnitude 0, Magnitu...
# 15                       (Magnitude Type ML, Month 1)
# 7   (Depth 0, Longitude 0, Magnitude 0, Magnitude ...
# 2   (Longitude 1, Magnitude 0, Magnitude Type ML, ...
# 14                   (Magnitude 0, Magnitude Type ML)
# 13                                     (Magnitude 0,)
#
#                                            Consequent  sup(A)  sup(B)  \
# 0                               (Region Name GREECE,)       2       2
# 11                                      (Latitude 3,)       4       4
# 12  (Day 0, Latitude 2, Region Name ISLAND OF HAWA...       2       2
# 8   (Latitude 2, Region Name ISLAND OF HAWAII, HAW...       4       4
# 16                                          (Year 0,)       8       7
# 5   (Latitude 2, Region Name ISLAND OF HAWAII, HAW...       3       4
# 6   (Latitude 2, Region Name ISLAND OF HAWAII, HAW...       3       4
# 9                                       (Latitude 3,)       3       4
# 10                                      (Latitude 3,)       3       4
# 4                                          (Depth 1,)       2       3
# 1                                            (Day 2,)       2       3
# 3                                            (Day 1,)       2       3
# 15                                          (Year 0,)       6       7
# 7   (Latitude 2, Region Name ISLAND OF HAWAII, HAW...       2       4
# 2                                       (Latitude 3,)       2       4
# 14                                         (Month 1,)       5       6
# 13                               (Magnitude Type ML,)       6       8
#
#     sup(A U B)  Kulczynski        IR
# 0            2      1.0000  0.000000
# 11           4      1.0000  0.000000
# 12           2      1.0000  0.000000
# 8            4      1.0000  0.000000
# 16           7      0.9375  0.125000
# 5            3      0.8750  0.250000
# 6            3      0.8750  0.250000
# 9            3      0.8750  0.250000
# 10           3      0.8750  0.250000
# 4            2      0.8333  0.333333
# 1            2      0.8333  0.333333
# 3            2      0.8333  0.333333
# 15           5      0.7738  0.125000
# 7            2      0.7500  0.500000
# 2            2      0.7500  0.500000
# 14           4      0.7333  0.142857
# 13           5      0.7292  0.222222

# %%
KulcValue = AssosiationRulesDataFrameForGA['Kulczynski']

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# Make a fake dataset:
height = KulcValue
bars = KulcValue.index.values
y_pos = np.arange(len(bars))
 
# Create bars
plt.bar(y_pos, height)
# Add title and axis names
plt.title('Kulczynski Values from Each Association Rules')
plt.xlabel('Association Rules Number')
plt.ylabel('Kulczynski Value')

 
# Create names on the x-axis
plt.xticks(y_pos, bars)
# Show graphic
plt.show()

# %%
CrossOverProbability = 0.8
MutationProbability = 0.01

# %%
BestAssociationRulesDataFrame = AssosiationRulesDataFrameForGA

# %%
constanta = len(AssociationRules)

# %%
constanta
# Out:
# 17

# %%
BestAssociationRulesDataFrame
# Out:
#                                                 Rules  \
# 0   If ['Depth 1', 'Latitude 3', 'Longitude 1', 'M...
# 11  If ['Longitude 1', 'Magnitude Type ML', 'Year ...
# 12  If ['Depth 0', 'Longitude 0', 'Magnitude Type ...
# 8   If ['Depth 0', 'Longitude 0'], Then ['Latitude...
# 16          If ['Magnitude Type ML'], Then ['Year 0']
# 5   If ['Depth 0', 'Longitude 0', 'Magnitude 0'], ...
# 6   If ['Depth 0', 'Longitude 0', 'Magnitude Type ...
# 9   If ['Longitude 1', 'Magnitude Type ML', 'Month...
# 10  If ['Longitude 1', 'Magnitude 0', 'Magnitude T...
# 4   If ['Day 0', 'Latitude 3', 'Longitude 1', 'Mag...
# 1       If ['Longitude 0', 'Month 0'], Then ['Day 2']
# 3   If ['Latitude 3', 'Longitude 1', 'Magnitude 0'...
# 15  If ['Magnitude Type ML', 'Month 1'], Then ['Ye...
# 7   If ['Depth 0', 'Longitude 0', 'Magnitude 0', '...
# 2   If ['Longitude 1', 'Magnitude 0', 'Magnitude T...
# 14  If ['Magnitude 0', 'Magnitude Type ML'], Then ...
# 13     If ['Magnitude 0'], Then ['Magnitude Type ML']
#
#                                           Antecedence  \
# 0   (Depth 1, Latitude 3, Longitude 1, Magnitude T...
# 11           (Longitude 1, Magnitude Type ML, Year 0)
# 12  (Depth 0, Longitude 0, Magnitude Type ML, Mont...
# 8                              (Depth 0, Longitude 0)
# 16                               (Magnitude Type ML,)
# 5                 (Depth 0, Longitude 0, Magnitude 0)
# 6   (Depth 0, Longitude 0, Magnitude Type ML, Mont...
# 9   (Longitude 1, Magnitude Type ML, Month 1, Year 0)
# 10  (Longitude 1, Magnitude 0, Magnitude Type ML, ...
# 4   (Day 0, Latitude 3, Longitude 1, Magnitude Typ...
# 1                              (Longitude 0, Month 0)
# 3   (Latitude 3, Longitude 1, Magnitude 0, Magnitu...
# 15                       (Magnitude Type ML, Month 1)
# 7   (Depth 0, Longitude 0, Magnitude 0, Magnitude ...
# 2   (Longitude 1, Magnitude 0, Magnitude Type ML, ...
# 14                   (Magnitude 0, Magnitude Type ML)
# 13                                     (Magnitude 0,)
#
#                                            Consequent  sup(A)  sup(B)  \
# 0                               (Region Name GREECE,)       2       2
# 11                                      (Latitude 3,)       4       4
# 12  (Day 0, Latitude 2, Region Name ISLAND OF HAWA...       2       2
# 8   (Latitude 2, Region Name ISLAND OF HAWAII, HAW...       4       4
# 16                                          (Year 0,)       8       7
# 5   (Latitude 2, Region Name ISLAND OF HAWAII, HAW...       3       4
# 6   (Latitude 2, Region Name ISLAND OF HAWAII, HAW...       3       4
# 9                                       (Latitude 3,)       3       4
# 10                                      (Latitude 3,)       3       4
# 4                                          (Depth 1,)       2       3
# 1                                            (Day 2,)       2       3
# 3                                            (Day 1,)       2       3
# 15                                          (Year 0,)       6       7
# 7   (Latitude 2, Region Name ISLAND OF HAWAII, HAW...       2       4
# 2                                       (Latitude 3,)       2       4
# 14                                         (Month 1,)       5       6
# 13                               (Magnitude Type ML,)       6       8
#
#     sup(A U B)  Kulczynski        IR
# 0            2      1.0000  0.000000
# 11           4      1.0000  0.000000
# 12           2      1.0000  0.000000
# 8            4      1.0000  0.000000
# 16           7      0.9375  0.125000
# 5            3      0.8750  0.250000
# 6            3      0.8750  0.250000
# 9            3      0.8750  0.250000
# 10           3      0.8750  0.250000
# 4            2      0.8333  0.333333
# 1            2      0.8333  0.333333
# 3            2      0.8333  0.333333
# 15           5      0.7738  0.125000
# 7            2      0.7500  0.500000
# 2            2      0.7500  0.500000
# 14           4      0.7333  0.142857
# 13           5      0.7292  0.222222

# %%
    # for step in range(1, 2):    
    # Data Yang Mau Diolah Masuk
    BestAssociationRulesDataFrame
    AssosiationRulesDataFrameForGA = pd.DataFrame({'Rules': FindAnteConse(RulesForGA),
                                          'Antecedence': FindAntecedence(RulesForGA) ,
                                          'Consequent': FindConsequent(RulesForGA) ,
                                          'sup(A)': CheckSupport(FindAntecedence(RulesForGA)),
                                          'sup(B)' : CheckSupport(FindConsequent(RulesForGA)),
                                          'sup(A U B)' : CheckSupport(FindAntecedenceConsequent(RulesForGA))
                                        })

    AssosiationRulesDataFrameForGA['Kulczynski'] = round((AssosiationRulesDataFrameForGA['sup(A U B)'] / 2) * ( ( 1/AssosiationRulesDataFrameForGA['sup(A)'] ) +  ( 1/AssosiationRulesDataFrameForGA['sup(B)'] )), 4)
    AssosiationRulesDataFrameForGA['IR'] = (abs(AssosiationRulesDataFrameForGA['sup(A)'] - AssosiationRulesDataFrameForGA['sup(B)'])) / (AssosiationRulesDataFrameForGA['sup(A)'] + AssosiationRulesDataFrameForGA['sup(B)'] - AssosiationRulesDataFrameForGA['sup(A U B)'])
    AssosiationRulesDataFrameForGA = AssosiationRulesDataFrameForGA.sort_values('Kulczynski', ascending=False)
    AssosiationRulesDataFrameForGA = AssosiationRulesDataFrameForGA[AssosiationRulesDataFrameForGA['sup(A)'] >= minsup]
    AssosiationRulesDataFrameForGA = AssosiationRulesDataFrameForGA[AssosiationRulesDataFrameForGA['sup(B)'] >= minsup]
    AssosiationRulesDataFrameForGA = AssosiationRulesDataFrameForGA[AssosiationRulesDataFrameForGA['sup(A U B)'] >= minsup]
    
    # Hitung Fitness
    fitness = []
    for i in AssosiationRulesDataFrameForGA['Kulczynski']:
        value = float((("{:.6f}".format(i))))
        fitness.append(value)
    fitness = sorted(fitness, reverse=True)
    
    # Hitung total fitness
    total_fitness = round(sum(fitness),6)
    
    # Fitness Individu / Fitness Total
    fitness_per_total = []
    for i in fitness:
        temp = (round((i / total_fitness),6))
        fitness_per_total.append(temp)
    
    # Fitness Individu / Fitness Total displayed on DataFrame
    Fitness_DataFrame = pd.DataFrame({'Fitness Value': fitness,
                    'Total Fitness': total_fitness,
                    'Result': fitness_per_total})
    
    # Give ID for each fitness value
    IndexIndividual = []
    for i in range(len(fitness_per_total)):
        IndexIndividual.append(i)
    
    # ID and fitness to dict
    BeginningIndividual = dict(zip(IndexIndividual, fitness_per_total))
    
    # =============================================== SELECTION =============================================== 
    # Do Roulette Wheel
    RouletteResult = []
    for i in range(len(fitness)):
        temp = RouletteWheel(BeginningIndividual)
        if temp not in RouletteResult:
            RouletteResult.append(temp)
        
    print('Roullete Result :',RouletteResult)
    print('=============================================================================================================')
            
    IndividualValue = round(len(RouletteResult) * CrossOverProbability)

    # Update IndividualValue, If odd, IndividualValue - 1
    if IndividualValue % 2 == 0:
        IndividualValue = IndividualValue
    else:
        IndividualValue = IndividualValue - 1
    IndividualValue
    
    print('Individual Value :',IndividualValue)
    print('=============================================================================================================')
    
    # Take some individu from RouletteResult based on IndividualValue
    RoulettePosition = RouletteResult[:IndividualValue]
    print('Roullete Position :',RoulettePosition)
    print('=============================================================================================================')
    
    ListOfAntecedence = AssosiationRulesDataFrameForGA['Antecedence']
    ListOfConsequent  = AssosiationRulesDataFrameForGA['Consequent']
    
    ListAntecedence = []
    for i in ListOfAntecedence:
        ListAntecedence.append(i)

    ListConsequent = []
    for i in ListOfConsequent:
        ListConsequent.append(i)
        
    MyAssociationRules = dict(zip(ListAntecedence, ListConsequent))
    
    s = []
    for a,b in MyAssociationRules.items():
        d = []
        d.append(a)
        d.append(b)
        s.append(d)
        
    # Rules awal setelah seleksi adalah sebanyak RulesForCrossover, dan itu yang akan digunakan ke tahap berikutnya
    RulesForCrossover = []
    for i in RoulettePosition:
        RulesForCrossover.append(s[i])
        
    # Pada Tahap ini, Rules awal dianggap sebagai Rules yang Baik
    # Diberikan fitness baru pada masing2 Rules Baik untuk melihat siapa saja yang akan terkena crossover
    FitnessForCrossover = []
    for i in range(len(RulesForCrossover)):
        Temp = round(random.uniform(0,1), 1)
        FitnessForCrossover.append(Temp)
    print('Fitness For Crossover :',FitnessForCrossover)
    print('=============================================================================================================')
    # List Rules dengan ID, Nilai Fitness, dan Rulesnya
    RulesWithFitnessCrossover = []
    for i in range(len(RulesForCrossover)):
        Temp = i,FitnessForCrossover[i], RulesForCrossover[i]
        RulesWithFitnessCrossover.append(Temp)
        
    print('Rules With Crossover Fitness', RulesWithFitnessCrossover)
    print('=============================================================================================================')
    
    # Tidak semua rules hasil seleksi akan di crossover. Rules yang akan di crossover adalah rules yang fitnessnya lebih rendah dari CP
    RulesToCrossover = []
    for i in range(len(RulesWithFitnessCrossover)):
        if RulesWithFitnessCrossover[i][1] < CrossOverProbability:
            Temp = RulesWithFitnessCrossover[i][0], RulesWithFitnessCrossover[i][1], RulesWithFitnessCrossover[i][2]
            RulesToCrossover.append(Temp)

    RulesNotToCrossover = []
    for i in range(len(RulesWithFitnessCrossover)):
        if RulesWithFitnessCrossover[i][1] >= CrossOverProbability:
            Temp = RulesWithFitnessCrossover[i][2]
            RulesNotToCrossover.append(Temp)
    
#     print ('Rules awal adalah',len(RulesWithFitnessCrossover))
#     print ('dari',len(RulesWithFitnessCrossover),'Rules, ada',len(RulesToCrossover), 'yang mungkin di crossover.')
#     print ('Kemudian, ada',len(RulesNotToCrossover), 'Rules yang tidak mungkin di crossover')
    if len(RulesToCrossover) > 0:
        
        RulesToCrossover = sorted(RulesToCrossover, key=itemgetter(1))
    
        RulesFixToCrossover = [ ]
        RulesCanceledToCrossover = [ ]
        
        
        if len(RulesToCrossover) % 2 == 1:
            RulesFixToCrossover = RulesToCrossover[:len(RulesToCrossover) - 1]
            RulesCanceledToCrossover.append(RulesToCrossover[-1])
        
            ListOfRulesCanceledToCrossover = []
            for i in RulesCanceledToCrossover:
                Item = i[2]
                ListOfRulesCanceledToCrossover.append(Item)
            RulesNotToCrossover = RulesNotToCrossover + ListOfRulesCanceledToCrossover
        else:
            RulesFixToCrossover = RulesToCrossover
#             print('Rules yang fix mau di crossover adalah sebanyak' , len(RulesFixToCrossover))
            
            
        
        
    else:
#         RulesNotToCrossover = RulesToCrossover
        RulesNotToCrossover = RulesNotToCrossover
        
#     print ('Kemudian, dari',len(RulesToCrossover), 'rules yang mungkin di crossover, ada', len(RulesCanceledToCrossover),'Rules Batal Menjadi Calon Crossover')
    
    
#     print ('Maka pada akhirnya akan ada',len(RulesFixToCrossover), 'Rules yang Akan di Crossover')
#     print ('dan akan ada',len(RulesNotToCrossover), 'Rules yang Tidak di crossover')

    if len(RulesFixToCrossover) > 0:
    
        RulesForEncode = []
        for i in range(len(RulesFixToCrossover)):
            RulesForEncode.append(RulesFixToCrossover[i][2])
        RulesForEncode
        print('Rules For Crossover', RulesForEncode)
        print('=============================================================================================================')
        
        encode_result = Encode(RulesForEncode)
    
        # Pemasangan Individu
        Couple = []
        a = 0
        for i in range(int(len(RulesForEncode)/2)):
            b = a + 1
            c = [a,b]
            Couple.append(c)
            a = a + 1
            b = a + 1
            a = b
    
        print('Couple :', Couple)
        print('=============================================================================================================')
    
        RandomA = []
        RandomB = []
        for i in range(len(Couple)):
            RandomA.append(Couple[i][0])
            RandomB.append(Couple[i][1])
        
        ListEncodeByRandomA = [encode_result[i] for i in RandomA]
        ListEncodeByRandomB = [encode_result[i] for i in RandomB]
    
        CoupleForCrossover = tuple(zip(ListEncodeByRandomA, ListEncodeByRandomB))
        
        # Check Couple to Crossover
        # Pasangan dapat dipastikan dengan potongan kode dibawah
    #     for i in range(len(CoupleForCrossover)):
    #         print(Decode(CoupleForCrossover[i]))

        # Make a cutpoint for crossover
        TwoPoint = []
        for i in range(len(CoupleForCrossover)):
            RandomPoint = random.sample(range(1, len(CoupleForCrossover[0][0])), 2)
            TwoPoint.append(sorted(RandomPoint))
        
        print('TwoPoint', TwoPoint)
        print('=============================================================================================================')
        
        Offspring = []
        const = len(CoupleForCrossover[0][0])
        for i in range(len(CoupleForCrossover)):
            left,right = [],[]
            for x in range(0, TwoPoint[i][0]):
                left.append(CoupleForCrossover[i][0][x])
                right.append(CoupleForCrossover[i][1][x])
            for q in range(TwoPoint[i][0], TwoPoint[i][1]):
                left.append(CoupleForCrossover[i][1][q])
                right.append(CoupleForCrossover[i][0][q])
            for k in range(TwoPoint[i][1], const):
                left.append(CoupleForCrossover[i][0][k])
                right.append(CoupleForCrossover[i][1][k])
            Offspring.append(left)
            Offspring.append(right)
        
        # Make sure Offspring from Crossover is not fail
        NewOffspringAfterCrossover = []
        for i in range(len(Offspring)):
            TempOffspring = Offspring[i]
            if ('00') in TempOffspring and ('11') in TempOffspring:
                NewOffspringAfterCrossover.append(TempOffspring)
        NewOffspringAfterCrossover
        print('Offspring Crossover :',NewOffspringAfterCrossover)
        print('=============================================================================================================')
        BadRulesAfterCrossover = Decode(NewOffspringAfterCrossover)
    else:
        TempRules = Encode(RulesForCrossover)
        OriginalRules = Decode(TempRules)
        BadRulesAfterCrossover = OriginalRules
        
        
    AnteListOfBadRulesAfterCrossover = []
    ConseListOfBadRulesAfterCrossover = []
    for key,value in BadRulesAfterCrossover.items():
        AnteListOfBadRulesAfterCrossover.append(key)
        ConseListOfBadRulesAfterCrossover.append(value)
        
    ListOfBadRulesAfterCrossover = []
    for i in range(len(BadRulesAfterCrossover)):
        Rules = [AnteListOfBadRulesAfterCrossover[i], ConseListOfBadRulesAfterCrossover[i]]
        ListOfBadRulesAfterCrossover.append(Rules)
    
    # Join Offspring From Crossover to RulesNotToCrossover
    OffspringFromCrossover = ListOfBadRulesAfterCrossover + RulesNotToCrossover

    EncodeForMutation = Encode(OffspringFromCrossover)
    
    ProbabilityMutation = round((len(EncodeForMutation) * len(EncodeForMutation[0]) * MutationProbability) / len(EncodeForMutation))
    FitnessForMutation = []
    for i in EncodeForMutation:
        Temp = []
        for j in range(len(i)):
            Temp.append(round(random.uniform(0,1), 3))
        FitnessForMutation.append(Temp)
    print('Fitness For Mutation', FitnessForMutation)
    print('=============================================================================================================')
    
    
    RulesToMutation = []
    RulesNotToMutation = []
    for i in range(len(FitnessForMutation)):
        if min(FitnessForMutation[i]) < MutationProbability:
            RulesToMutation.append(EncodeForMutation[i])
        else:
            RulesNotToMutation.append(EncodeForMutation[i])
            
    if len(RulesNotToMutation) > 0:
        print('Rules to Mutation',RulesToMutation)
        print('=============================================================================================================')
        MutationPoint = ListOfMutationPoints(RulesToMutation, ProbabilityMutation)
        print('Mutation Point', MutationPoint)
        print('=============================================================================================================')
        # MUTASI
        change = {
                    '00' : '11',
                    '01' : '10',
                    '10' : '01',
                    '11' : '00'
                }

        for i in range(len(MutationPoint)):
            for j in range(len(MutationPoint[i])):
                RulesToMutation[i][MutationPoint[i][j]] = change[RulesToMutation[i][MutationPoint[i][j]]]



        NewOffspringAfterMutation = []
        for i in range(len(RulesToMutation)):
            TempOffspring = RulesToMutation[i]
            if ('00') in TempOffspring and ('11') in TempOffspring:
                NewOffspringAfterMutation.append(TempOffspring)

        print('Offspring From Mutation', NewOffspringAfterMutation)
        print('=============================================================================================================')
        OffspringFromMutation = RulesNotToMutation + NewOffspringAfterMutation
    else:
        OffspringFromMutation = OffspringFromCrossover
    print('Offspring From Mutation', OffspringFromCrossover)
    print('=============================================================================================================')
    RulesForGA = Decode(OffspringFromMutation)
    
    
    AssosiationRulesDataFrameAfterGA = pd.DataFrame({'Rules': FindAnteConse(RulesForGA),
                                          'Antecedence': FindAntecedence(RulesForGA),
                                          'Consequent': FindConsequent(RulesForGA),
                                          'sup(A)': CheckSupport(FindAntecedence(RulesForGA)),
                                          'sup(B)' : CheckSupport(FindConsequent(RulesForGA)),
                                          'sup(A U B)' : CheckSupport(FindAntecedenceConsequent(RulesForGA))
                                        })
    
    AssosiationRulesDataFrameAfterGA['Kulczynski'] = round((AssosiationRulesDataFrameAfterGA['sup(A U B)'] / 2) * ( ( 1/AssosiationRulesDataFrameAfterGA['sup(A)'] ) +  ( 1/AssosiationRulesDataFrameAfterGA['sup(B)'] )), 4)
    AssosiationRulesDataFrameAfterGA['IR'] = (abs(AssosiationRulesDataFrameAfterGA['sup(A)'] - AssosiationRulesDataFrameAfterGA['sup(B)'])) / (AssosiationRulesDataFrameAfterGA['sup(A)'] + AssosiationRulesDataFrameAfterGA['sup(B)'] - AssosiationRulesDataFrameAfterGA['sup(A U B)'])
    AssosiationRulesDataFrameAfterGA = AssosiationRulesDataFrameAfterGA.sort_values('Kulczynski', ascending=False)
    AssosiationRulesDataFrameAfterGA = AssosiationRulesDataFrameAfterGA[AssosiationRulesDataFrameAfterGA['sup(A)'] >= minsup]
    AssosiationRulesDataFrameAfterGA = AssosiationRulesDataFrameAfterGA[AssosiationRulesDataFrameAfterGA['sup(B)'] >= minsup]
    AssosiationRulesDataFrameAfterGA = AssosiationRulesDataFrameAfterGA[AssosiationRulesDataFrameAfterGA['sup(A U B)'] >= minsup]
    
#     AssosiationRulesDataFrameAfterGA.to_csv("Hasil/Hasil Optimasi Iterasi ke - " + str(step) + ".csv", index = False)
    

#     DataFrame untuk Offspring namanya AssosiationRulesDataFrameAfterGA 
#     AssosiationRulesDataFrameAfterGA.to_csv("Hasil/Hasil Optimasi Iterasi ke - " + str(step) + ".csv", index = False)
    
    new_df = pd.concat([AssosiationRulesDataFrameAfterGA, BestAssociationRulesDataFrame])
    new_df = new_df.drop_duplicates()
    new_df_sorted = new_df.sort_values('Kulczynski', ascending=False)
    BestRules = new_df_sorted.head(constanta)
#     BestRules.to_csv("Hasil/Final Rules/Kondisi Rules Iterasi ke - " + str(step) + ".csv", index = False)
    NewAntecedenceForIteration = BestRules['Antecedence']
    NewConsequentForIteration = BestRules['Consequent']
    DictOfNewRules = dict(zip(NewAntecedenceForIteration, NewConsequentForIteration))
    RulesForGA = DictOfNewRules
    BestAssociationRulesDataFrame = BestRules
# Out:
# Roullete Result : [11, 9, 8, 1, 6, 7, 4, 5, 16, 2]
# =============================================================================================================
# Individual Value : 8
# =============================================================================================================
# Roullete Position : [11, 9, 8, 1, 6, 7, 4, 5]
# =============================================================================================================
# Fitness For Crossover : [0.6, 0.2, 1.0, 0.1, 0.2, 0.4, 0.6, 0.9]
# =============================================================================================================
# Rules With Crossover Fitness [(0, 0.6, [('Latitude 3', 'Longitude 1', 'Magnitude Type ML', 'Year 0'), ('Depth 1',)]), (1, 0.2, [('Depth 1',), ('Latitude 3', 'Longitude 1')]), (2, 1.0, [('Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII'), ('Depth 0', 'Longitude 0', 'Magnitude Type ML', 'Month 1')]), (3, 0.1, [('Depth 1', 'Latitude 3', 'Longitude 1', 'Magnitude Type ML', 'Month 1', 'Year 0'), ('Region Name GREECE',)]), (4, 0.2, [('Latitude 3', 'Year 0'), ('Longitude 1',)]), (5, 0.4, [('Longitude 1', 'Magnitude 0', 'Magnitude Type ML', 'Year 0'), ('Latitude 3',)]), (6, 0.6, [('Depth 0', 'Longitude 0'), ('Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII')]), (7, 0.9, [('Magnitude Type ML',), ('Year 0',)])]
# =============================================================================================================
# Rules For Crossover [[('Depth 1', 'Latitude 3', 'Longitude 1', 'Magnitude Type ML', 'Month 1', 'Year 0'), ('Region Name GREECE',)], [('Depth 1',), ('Latitude 3', 'Longitude 1')], [('Latitude 3', 'Year 0'), ('Longitude 1',)], [('Longitude 1', 'Magnitude 0', 'Magnitude Type ML', 'Year 0'), ('Latitude 3',)], [('Latitude 3', 'Longitude 1', 'Magnitude Type ML', 'Year 0'), ('Depth 1',)], [('Depth 0', 'Longitude 0'), ('Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII')]]
# =============================================================================================================
# Couple : [[0, 1], [2, 3], [4, 5]]
# =============================================================================================================
# TwoPoint [[6, 20], [9, 27], [4, 15]]
# =============================================================================================================
# Offspring Crossover : [['00', '01', '01', '01', '01', '11', '01', '01', '01', '01', '01', '01', '11', '01', '11', '01', '00', '01', '01', '01', '01', '01', '00', '01', '01', '00', '01', '01', '01'], ['01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '11', '01', '00', '01', '01', '01', '01', '00', '01', '01', '00', '01', '01', '01', '01', '01', '01'], ['00', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '00', '01', '11', '01', '01', '01', '01', '01', '01', '01', '00', '01', '01', '01', '01', '01', '01'], ['00', '01', '01', '01', '01', '01', '11', '01', '01', '01', '01', '11', '01', '00', '01', '01', '11', '01', '01', '01', '01', '01', '00', '01', '01', '01', '01', '01', '01']]
# =============================================================================================================
# Fitness For Mutation [[0.867, 0.674, 0.746, 0.172, 0.212, 0.423, 0.595, 0.563, 0.643, 0.612, 0.977, 0.15, 0.362, 0.553, 0.27, 0.59, 0.351, 0.238, 0.596, 0.979, 0.661, 0.865, 0.73, 0.434, 0.541, 0.282, 0.996, 0.329, 0.699], [0.267, 0.699, 0.715, 0.565, 0.16, 0.155, 0.783, 0.201, 0.655, 0.072, 0.2, 0.869, 0.015, 0.549, 0.252, 0.636, 0.953, 0.59, 0.572, 0.1, 0.042, 0.374, 0.572, 0.207, 0.246, 0.156, 0.145, 0.149, 0.753], [0.129, 0.355, 0.942, 0.109, 0.094, 0.563, 0.317, 0.301, 0.844, 0.163, 0.36, 0.824, 0.127, 0.362, 0.068, 0.747, 0.971, 0.586, 0.757, 0.419, 0.648, 0.277, 0.584, 0.91, 0.45, 0.725, 0.776, 0.178, 0.547], [0.456, 0.001, 0.605, 0.804, 0.47, 0.678, 0.285, 0.42, 0.112, 0.392, 0.743, 0.328, 0.318, 0.688, 0.827, 0.183, 0.714, 0.483, 0.332, 0.655, 0.315, 0.51, 0.56, 0.752, 0.043, 0.699, 0.332, 0.374, 0.432], [0.719, 0.675, 0.801, 0.785, 0.017, 0.064, 0.903, 0.937, 0.665, 0.91, 0.773, 0.713, 0.605, 0.581, 0.101, 0.34, 0.103, 0.876, 0.128, 0.071, 0.389, 0.164, 0.958, 0.405, 0.637, 0.341, 0.568, 0.706, 0.667], [0.452, 0.112, 0.158, 0.377, 0.471, 0.805, 0.93, 0.108, 0.18, 0.084, 0.206, 0.684, 0.893, 0.532, 0.04, 0.3, 0.729, 0.33, 0.277, 0.051, 0.854, 0.777, 0.005, 0.553, 0.055, 0.754, 0.043, 0.843, 0.592]]
# =============================================================================================================
# Rules to Mutation [['00', '01', '01', '01', '01', '01', '11', '01', '01', '01', '01', '11', '01', '00', '01', '01', '11', '01', '01', '01', '01', '01', '00', '01', '01', '01', '01', '01', '01'], ['00', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '11', '01', '01', '01', '01', '01', '01']]
# =============================================================================================================
# Mutation Point [[], []]
# =============================================================================================================
# Offspring From Mutation [['00', '01', '01', '01', '01', '01', '11', '01', '01', '01', '01', '11', '01', '00', '01', '01', '11', '01', '01', '01', '01', '01', '00', '01', '01', '01', '01', '01', '01'], ['00', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '11', '01', '01', '01', '01', '01', '01']]
# =============================================================================================================
# Offspring From Mutation [[('Magnitude Type ML', 'Depth 1', 'Year 0', 'Month 1'), ('Region Name GREECE', 'Latitude 3', 'Longitude 1')], [('Longitude 1', 'Magnitude 0', 'Year 0'), ('Latitude 3',)], [('Magnitude Type ML', 'Latitude 3', 'Year 0'), ('Longitude 1',)], [('Magnitude Type ML', 'Longitude 0', 'Year 0'), ('Region Name ISLAND OF HAWAII, HAWAII', 'Latitude 2', 'Depth 1')], [('Latitude 2', 'Region Name ISLAND OF HAWAII, HAWAII'), ('Depth 0', 'Longitude 0', 'Magnitude Type ML', 'Month 1')], [('Magnitude Type ML',), ('Year 0',)]]
# =============================================================================================================

# %%
BestRules
# Out:
#                                                Rules  \
# 0  If ['Depth 1', 'Magnitude Type ML', 'Month 1',...
# 6  If ['Depth 1', 'Latitude 3', 'Longitude 1', 'M...
# 7  If ['Longitude 1', 'Region Name GREECE'], Then...
# 2  If ['Longitude 1', 'Magnitude Type ML', 'Year ...
# 1  If ['Depth 0', 'Longitude 0', 'Magnitude Type ...
# 6  If ['Depth 0', 'Longitude 0'], Then ['Latitude...
# 5          If ['Magnitude Type ML'], Then ['Year 0']
# 5  If ['Latitude 3', 'Year 0'], Then ['Longitude 1']
# 2  If ['Latitude 3', 'Magnitude Type ML', 'Year 0...
# 3  If ['Latitude 2', 'Region Name ISLAND OF HAWAI...
# 1  If ['Longitude 1', 'Magnitude 0', 'Year 0'], T...
# 5  If ['Longitude 1', 'Magnitude 0'], Then ['Lati...
# 3  If ['Latitude 3', 'Longitude 1', 'Magnitude Ty...
# 4  If ['Longitude 1', 'Magnitude Type ML', 'Month...
# 1  If ['Depth 0', 'Longitude 0', 'Magnitude Type ...
# 0  If ['Latitude 3', 'Longitude 1', 'Magnitude Ty...
# 5  If ['Longitude 1', 'Magnitude 0', 'Magnitude T...
#
#                                          Antecedence  \
# 0      (Depth 1, Magnitude Type ML, Month 1, Year 0)
# 6  (Depth 1, Latitude 3, Longitude 1, Magnitude T...
# 7                  (Longitude 1, Region Name GREECE)
# 2           (Longitude 1, Magnitude Type ML, Year 0)
# 1  (Depth 0, Longitude 0, Magnitude Type ML, Mont...
# 6                             (Depth 0, Longitude 0)
# 5                               (Magnitude Type ML,)
# 5                               (Latitude 3, Year 0)
# 2            (Latitude 3, Magnitude Type ML, Year 0)
# 3  (Latitude 2, Region Name ISLAND OF HAWAII, HAW...
# 1                 (Longitude 1, Magnitude 0, Year 0)
# 5                         (Longitude 1, Magnitude 0)
# 3  (Latitude 3, Longitude 1, Magnitude Type ML, Y...
# 4  (Longitude 1, Magnitude Type ML, Month 1, Year 0)
# 1  (Depth 0, Longitude 0, Magnitude Type ML, Mont...
# 0       (Latitude 3, Longitude 1, Magnitude Type ML)
# 5  (Longitude 1, Magnitude 0, Magnitude Type ML, ...
#
#                                           Consequent  sup(A)  sup(B)  \
# 0      (Latitude 3, Longitude 1, Region Name GREECE)       2       2
# 6                              (Region Name GREECE,)       2       2
# 7  (Depth 1, Latitude 3, Magnitude Type ML, Month...       2       2
# 2                                      (Latitude 3,)       4       4
# 1  (Day 0, Latitude 2, Region Name ISLAND OF HAWA...       2       2
# 6  (Latitude 2, Region Name ISLAND OF HAWAII, HAW...       4       4
# 5                                          (Year 0,)       8       7
# 5                                     (Longitude 1,)       4       5
# 2                                     (Longitude 1,)       4       5
# 3  (Depth 0, Longitude 0, Magnitude Type ML, Mont...       4       3
# 1                                      (Latitude 3,)       3       4
# 5                    (Latitude 3, Magnitude Type ML)       3       4
# 3                                         (Depth 1,)       4       3
# 4                                      (Latitude 3,)       3       4
# 1  (Latitude 2, Region Name ISLAND OF HAWAII, HAW...       3       4
# 0                                         (Depth 1,)       4       3
# 5                                      (Latitude 3,)       3       4
#
#    sup(A U B)  Kulczynski     IR
# 0           2      1.0000  0.000
# 6           2      1.0000  0.000
# 7           2      1.0000  0.000
# 2           4      1.0000  0.000
# 1           2      1.0000  0.000
# 6           4      1.0000  0.000
# 5           7      0.9375  0.125
# 5           4      0.9000  0.200
# 2           4      0.9000  0.200
# 3           3      0.8750  0.250
# 1           3      0.8750  0.250
# 5           3      0.8750  0.250
# 3           3      0.8750  0.250
# 4           3      0.8750  0.250
# 1           3      0.8750  0.250
# 0           3      0.8750  0.250
# 5           3      0.8750  0.250
